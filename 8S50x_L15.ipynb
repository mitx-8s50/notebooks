# %% [markdown]
# <hr style="height: 1px;">
# <i>This notebook was authored by the 8.S50x Course Team, Copyright 2022 MIT All Rights Reserved.</i>
# <hr style="height: 1px;">
# <br>
#
# <h1>Lesson 15: Cosmic Microwave Background Analysis</h1>

# %% [markdown]
# <a name='section_15_0'></a>
# <hr style="height: 1px;">
#
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L15.0 Overview</h2>

# %% [markdown]
# <table style="width:100%">
#     <colgroup>
#        <col span="1" style="width: 40%;">
#        <col span="1" style="width: 15%;">
#        <col span="1" style="width: 45%;">
#     </colgroup>
#     <tr>
#         <th style="text-align: left; font-size: 13pt;">Section</th>
#         <th style="text-align: left; font-size: 13pt;">Exercises</th>
#         <th style="text-align: left; font-size: 13pt;">Summary</th>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_15_1">L15.1 History of the Universe</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_15_1">L15.1 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_15_2">L15.2 Adiabatic Expansion and Redshift</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_15_2">L15.2 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_15_3">L15.3 Blackbody Radiation</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_15_3">L15.3 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_15_4">L15.4 Observed Characteristics of the CMB: Part I</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_15_4">L15.4 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_15_5">L15.5 Observed Characteristics of the CMB: Part II</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_15_5">L15.5 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_15_6">L15.6 Angular Power Spectrum Features</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_15_6">L15.6 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_15_7">L15.7 Cosmological Parameters</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_15_7">L15.7 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_15_8">L15.8 CMB Experiments and Data Analysis</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_15_8">L15.8 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_15_9">L15.9 Introduction to Project 3</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_15_9">L15.9 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <h3>Learning Objectives</h3>
#
# Text needed

# %% [markdown]
# <h3>Importing Libraries</h3>
#
# Before beginning, run the cell below to import the relevant libraries for this notebook.
# Optionally, set the plot resolution and default figure size.

# %%
#>>>RUN

import numpy as np

#set plot resolution
#%config InlineBackend.figure_format = 'retina'

#set default figure size
#plt.rcParams['figure.figsize'] = (9,6)

# %% [markdown]
# <a name='section_15_1'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L15.1 History of the Universe</h2>
#
# | [Top](#section_15_0) | [Previous Section](#section_15_0) | [Exercises](#exercises_15_1) | [Next Section](#section_15_2) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L15/slides_L15_01.html', width=970, height=550)
# Out:
#         <iframe
#             width="970"
#             height="550"
#             src="https://mitx-8s50.github.io/slides/L15/slides_L15_01.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <a name='exercises_15_1'></a>
#
# | [Top](#section_15_0) | [Restart Section](#section_15_1) | [Next Section](#section_15_2) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 15.1.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_15_2'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L15.2 Adiabatic Expansion and Redshift</h2>
#
# | [Top](#section_15_0) | [Previous Section](#section_15_1) | [Exercises](#exercises_15_2) | [Next Section](#section_15_3) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L15/slides_L15_02.html', width=970, height=550)

# %% [markdown]
# <a name='exercises_15_2'></a>
#
# | [Top](#section_15_0) | [Restart Section](#section_15_2) | [Next Section](#section_15_3) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 15.2.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_15_3'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L15.3 Blackbody Radiation</h2>
#
# | [Top](#section_15_0) | [Previous Section](#section_15_2) | [Exercises](#exercises_15_3) | [Next Section](#section_15_4) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L15/slides_L15_03.html', width=970, height=550)

# %% [markdown]
# <a name='exercises_15_3'></a>
#
# | [Top](#section_15_0) | [Restart Section](#section_15_3) | [Next Section](#section_15_4) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 15.3.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_15_4'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L15.4 Observed Characteristics of the CMB: Part I</h2>
#
# | [Top](#section_15_0) | [Previous Section](#section_15_3) | [Exercises](#exercises_15_4) | [Next Section](#section_15_5) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L15/slides_L15_04.html', width=970, height=550)

# %% [markdown]
# <a name='exercises_15_4'></a>
#
# | [Top](#section_15_0) | [Restart Section](#section_15_4) | [Next Section](#section_15_5) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 15.4.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_15_5'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L15.5 Observed Characteristics of the CMB: Part II</h2>
#
# | [Top](#section_15_0) | [Previous Section](#section_15_4) | [Exercises](#exercises_15_5) | [Next Section](#section_15_6) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L15/slides_L15_05.html', width=970, height=550)

# %% [markdown]
# <a name='exercises_15_5'></a>
#
# | [Top](#section_15_0) | [Restart Section](#section_15_5) | [Next Section](#section_15_6) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 15.5.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_15_6'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L15.6 Angular Power Spectrum Features</h2>
#
# | [Top](#section_15_0) | [Previous Section](#section_15_5) | [Exercises](#exercises_15_6) | [Next Section](#section_15_7) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L15/slides_L15_06.html', width=970, height=550)

# %% [markdown]
# <a name='exercises_15_6'></a>
#
# | [Top](#section_15_0) | [Restart Section](#section_15_6) | [Next Section](#section_15_7) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 15.6.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_15_7'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L15.7 Cosmological Parameters</h2>
#
# | [Top](#section_15_0) | [Previous Section](#section_15_6) | [Exercises](#exercises_15_7) | [Next Section](#section_15_8) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L15/slides_L15_07.html', width=970, height=550)

# %% [markdown]
# <a name='exercises_15_7'></a>
#
# | [Top](#section_15_0) | [Restart Section](#section_15_7) | [Next Section](#section_15_8) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 15.7.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_15_8'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L15.8 CMB Experiments and Data Analysis</h2>
#
# | [Top](#section_15_0) | [Previous Section](#section_15_7) | [Exercises](#exercises_15_8) | [Next Section](#section_15_9) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L15/slides_L15_08.html', width=970, height=550)

# %% [markdown]
# <a name='exercises_15_8'></a>
#
# | [Top](#section_15_0) | [Restart Section](#section_15_8) | [Next Section](#section_15_9) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 15.8.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_15_9'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L15.9 Introduction to Project 3</h2>
#
# | [Top](#section_15_0) | [Previous Section](#section_15_8) | [Exercises](#exercises_15_9) |

# %% [markdown]
# <h3>Overview</h3>
#
# TEXT

# %%
#>>>RUN

#code

# %% [markdown]
# <a name='exercises_15_9'></a>
#
# | [Top](#section_15_0) | [Restart Section](#section_15_9) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 15.9.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>
