# %% [markdown]
# <hr style="height: 1px;">
# <i>This notebook was authored by the 8.S50x Course Team, Copyright 2022 MIT All Rights Reserved.</i>
# <hr style="height: 1px;">
# <br>
#
# <h1>Lesson 21: Guest Lecture: Particle Physics Meets Machine Learning</h1>

# %% [markdown]
# <a name='section_21_0'></a>
# <hr style="height: 1px;">
#
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L21.0 Overview</h2>

# %% [markdown]
# <table style="width:100%">
#     <colgroup>
#        <col span="1" style="width: 40%;">
#        <col span="1" style="width: 15%;">
#        <col span="1" style="width: 45%;">
#     </colgroup>
#     <tr>
#         <th style="text-align: left; font-size: 13pt;">Section</th>
#         <th style="text-align: left; font-size: 13pt;">Exercises</th>
#         <th style="text-align: left; font-size: 13pt;">Summary</th>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_21_1">L21.1 Part 1</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_21_1">L21.1 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_21_2">L21.2 Part 2</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_21_2">L21.2 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_21_3">L21.3 Part 3</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_21_3">L21.3 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_21_4">L21.4 Part 4</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_21_4">L21.4 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_21_5">L21.5 Part 5</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_21_5">L21.5 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_21_6">L21.6 Part 6</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_21_6">L21.6 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_21_7">L21.7 Part 7</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_21_7">L21.7 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_21_8">L21.8 Discussion</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_21_8">L21.8 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <h3>Learning Objectives</h3>
#
# Text needed

# %% [markdown]
# <h3>Importing Libraries</h3>
#
# Before beginning, run the cell below to import the relevant libraries for this notebook.
# Optionally, set the plot resolution and default figure size.

# %%
#>>>RUN

import numpy as np

#set plot resolution
#%config InlineBackend.figure_format = 'retina'

#set default figure size
#plt.rcParams['figure.figsize'] = (9,6)

# %% [markdown]
# <a name='section_21_1'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L21.1 Part 1</h2>
#
# | [Top](#section_21_0) | [Previous Section](#section_21_0) | [Exercises](#exercises_21_1) | [Next Section](#section_21_2) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L21/slides_L21_01.html', width=970, height=550)
# Out:
#         <iframe
#             width="970"
#             height="550"
#             src="https://mitx-8s50.github.io/slides/L21/slides_L21_01.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <a name='exercises_21_1'></a>
#
# | [Top](#section_21_0) | [Restart Section](#section_21_1) | [Next Section](#section_21_2) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 21.1.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_21_2'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L21.2 Part 2</h2>
#
# | [Top](#section_21_0) | [Previous Section](#section_21_1) | [Exercises](#exercises_21_2) | [Next Section](#section_21_3) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L21/slides_L21_02.html', width=970, height=550)
# Out:
#         <iframe
#             width="970"
#             height="550"
#             src="images/slides_L21_02.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <a name='exercises_21_2'></a>
#
# | [Top](#section_21_0) | [Restart Section](#section_21_2) | [Next Section](#section_21_3) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 21.2.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_21_3'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L21.3 Part 3</h2>
#
# | [Top](#section_21_0) | [Previous Section](#section_21_2) | [Exercises](#exercises_21_3) | [Next Section](#section_21_4) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L21/slides_L21_03.html', width=970, height=550)
# Out:
#         <iframe
#             width="970"
#             height="550"
#             src="images/slides_L21_03.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <a name='exercises_21_3'></a>
#
# | [Top](#section_21_0) | [Restart Section](#section_21_3) | [Next Section](#section_21_4) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 21.3.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_21_4'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L21.4 Part 4</h2>
#
# | [Top](#section_21_0) | [Previous Section](#section_21_3) | [Exercises](#exercises_21_4) | [Next Section](#section_21_5) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L21/slides_L21_04.html', width=970, height=550)
# Out:
#         <iframe
#             width="970"
#             height="550"
#             src="images/slides_L21_04.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <a name='exercises_21_4'></a>
#
# | [Top](#section_21_0) | [Restart Section](#section_21_4) | [Next Section](#section_21_5) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 21.4.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_21_5'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L21.5 Part 5</h2>
#
# | [Top](#section_21_0) | [Previous Section](#section_21_4) | [Exercises](#exercises_21_5) | [Next Section](#section_21_6) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L21/slides_L21_05.html', width=970, height=550)
# Out:
#         <iframe
#             width="970"
#             height="550"
#             src="images/slides_L21_05.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <a name='exercises_21_5'></a>
#
# | [Top](#section_21_0) | [Restart Section](#section_21_5) | [Next Section](#section_21_6) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 21.5.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_21_6'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L21.6 Part 6</h2>
#
# | [Top](#section_21_0) | [Previous Section](#section_21_5) | [Exercises](#exercises_21_6) | [Next Section](#section_21_7) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L21/slides_L21_06.html', width=970, height=550)
# Out:
#         <iframe
#             width="970"
#             height="550"
#             src="images/slides_L21_06.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <a name='exercises_21_6'></a>
#
# | [Top](#section_21_0) | [Restart Section](#section_21_6) | [Next Section](#section_21_7) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 21.6.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_21_7'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L21.7 Part 7</h2>
#
# | [Top](#section_21_0) | [Previous Section](#section_21_6) | [Exercises](#exercises_21_7) | [Next Section](#section_21_8) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L21/slides_L21_07.html', width=970, height=550)
# Out:
#         <iframe
#             width="970"
#             height="550"
#             src="https://mitx-8s50.github.io/slides/L21/slides_L21_07.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <a name='exercises_21_7'></a>
#
# | [Top](#section_21_0) | [Restart Section](#section_21_7) | [Next Section](#section_21_8) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 21.7.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_21_8'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L21.8 Discussion</h2>
#
# | [Top](#section_21_0) | [Previous Section](#section_21_7) | [Exercises](#exercises_21_8) |

# %% [markdown]
# <h3>Overview</h3>
#
# Text

# %%
#>>>RUN

#code

# %% [markdown]
# <a name='exercises_21_8'></a>
#
# | [Top](#section_21_0) | [Restart Section](#section_21_8) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 21.8.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>
