# %% [markdown]
# <hr style="height: 1px;">
# <i>This notebook was authored by the 8.S50x Course Team, Copyright 2022 MIT All Rights Reserved.</i>
# <hr style="height: 1px;">
# <br>
#
# <h1>Lesson 16: CMB Data Analysis Continued</h1>

# %% [markdown]
# <a name='section_16_0'></a>
# <hr style="height: 1px;">
#
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L16.0 Overview</h2>

# %% [markdown]
# <table style="width:100%">
#     <colgroup>
#        <col span="1" style="width: 40%;">
#        <col span="1" style="width: 15%;">
#        <col span="1" style="width: 45%;">
#     </colgroup>
#     <tr>
#         <th style="text-align: left; font-size: 13pt;">Section</th>
#         <th style="text-align: left; font-size: 13pt;">Exercises</th>
#         <th style="text-align: left; font-size: 13pt;">Summary</th>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_16_1">L16.1 Map Making</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_16_1">L16.1 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_16_2">L16.2 A Concrete Example: Part I</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_16_2">L16.2 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_16_3">L16.3 A Concrete Example: Part II</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_16_3">L16.3 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_16_4">L16.4 A Concrete Example: Part III</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_16_4">L16.4 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_16_5">L16.5 A Concrete Example: Part IV</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_16_5">L16.5 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_16_6">L16.6 A Concrete Example: Part V</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_16_6">L16.6 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <h3>Learning Objectives</h3>
#
# Text needed

# %% [markdown]
# <h3>Importing Libraries</h3>
#
# Before beginning, run the cell below to import the relevant libraries for this notebook.
# Optionally, set the plot resolution and default figure size.

# %%
#>>>RUN

import numpy as np

#set plot resolution
#%config InlineBackend.figure_format = 'retina'

#set default figure size
#plt.rcParams['figure.figsize'] = (9,6)

# %% [markdown]
# <a name='section_16_1'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L16.1 Map Making</h2>
#
# | [Top](#section_16_0) | [Previous Section](#section_16_0) | [Exercises](#exercises_16_1) | [Next Section](#section_16_2) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L16/slides_L16_01.html', width=970, height=550)
# Out:
#         <iframe
#             width="970"
#             height="550"
#             src="https://mitx-8s50.github.io/slides/L16/slides_L16_01.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <a name='exercises_16_1'></a>
#
# | [Top](#section_16_0) | [Restart Section](#section_16_1) | [Next Section](#section_16_2) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 16.1.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_16_2'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L16.2 A Concrete Example: Part I</h2>
#
# | [Top](#section_16_0) | [Previous Section](#section_16_1) | [Exercises](#exercises_16_2) | [Next Section](#section_16_3) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L16/slides_L16_02.html', width=970, height=550)
# Out:
#         <iframe
#             width="970"
#             height="550"
#             src="https://mitx-8s50.github.io/slides/L16/slides_L16_02.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <a name='exercises_16_2'></a>
#
# | [Top](#section_16_0) | [Restart Section](#section_16_2) | [Next Section](#section_16_3) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 16.2.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_16_3'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L16.3 A Concrete Example: Part II</h2>
#
# | [Top](#section_16_0) | [Previous Section](#section_16_2) | [Exercises](#exercises_16_3) | [Next Section](#section_16_4) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L16/slides_L16_03.html', width=970, height=550)

# %% [markdown]
# <a name='exercises_16_3'></a>
#
# | [Top](#section_16_0) | [Restart Section](#section_16_3) | [Next Section](#section_16_4) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 16.3.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_16_4'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L16.4 A Concrete Example: Part III</h2>
#
# | [Top](#section_16_0) | [Previous Section](#section_16_3) | [Exercises](#exercises_16_4) | [Next Section](#section_16_5) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L16/slides_L16_04.html', width=970, height=550)

# %% [markdown]
# <a name='exercises_16_4'></a>
#
# | [Top](#section_16_0) | [Restart Section](#section_16_4) | [Next Section](#section_16_5) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 16.4.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_16_5'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L16.5 A Concrete Example: Part IV</h2>
#
# | [Top](#section_16_0) | [Previous Section](#section_16_4) | [Exercises](#exercises_16_5) | [Next Section](#section_16_6) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L16/slides_L16_05.html', width=970, height=550)

# %% [markdown]
# <a name='exercises_16_5'></a>
#
# | [Top](#section_16_0) | [Restart Section](#section_16_5) | [Next Section](#section_16_6) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 16.5.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_16_6'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L16.6 A Concrete Example: Part V</h2>
#
# | [Top](#section_16_0) | [Previous Section](#section_16_5) | [Exercises](#exercises_16_6) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L16/slides_L16_06.html', width=970, height=550)

# %% [markdown]
# <a name='exercises_16_6'></a>
#
# | [Top](#section_16_0) | [Restart Section](#section_16_6) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 16.6.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>
