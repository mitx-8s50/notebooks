# %% [markdown]
# <hr style="height: 1px;">
# <i>This notebook was authored by the 8.S50x Course Team, Copyright 2022 MIT All Rights Reserved.</i>
# <hr style="height: 1px;">
# <br>
#
# <h1>Lesson 17: Power Spectrum Estimation</h1>

# %% [markdown]
# <a name='section_17_0'></a>
# <hr style="height: 1px;">
#
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L17.0 Overview</h2>

# %% [markdown]
# <table style="width:100%">
#     <colgroup>
#        <col span="1" style="width: 40%;">
#        <col span="1" style="width: 15%;">
#        <col span="1" style="width: 45%;">
#     </colgroup>
#     <tr>
#         <th style="text-align: left; font-size: 13pt;">Section</th>
#         <th style="text-align: left; font-size: 13pt;">Exercises</th>
#         <th style="text-align: left; font-size: 13pt;">Summary</th>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_17_1">L17.1 Power Spectrum</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_17_1">L17.1 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_17_2">L17.2 Random Processes</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_17_2">L17.2 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_17_3">L17.3 Spectra of Stationary Random Processes</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_17_3">L17.3 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_17_4">L17.4 Discrete Time-Ordered Data</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_17_4">L17.4 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_17_5">L17.5 Maximum Likelihood Signal Estimation</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_17_5">L17.5 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_17_6">L17.6 DFT Matrix</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_17_6">L17.6 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_17_7">L17.7 Noise-Weighting the Data</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_17_7">L17.7 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
#     <tr>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#section_17_8">L17.8 Map Power Spectrum</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;"><a href="#exercises_17_8">L17.8 Exercises</a></td>
#         <td style="text-align: left; vertical-align: top; font-size: 10pt;">
#             <ul>
#                 <li>text</li>
#                 <li>text</li>
#             </ul>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <h3>Learning Objectives</h3>
#
# Text needed

# %% [markdown]
# <h3>Importing Libraries</h3>
#
# Before beginning, run the cell below to import the relevant libraries for this notebook.
# Optionally, set the plot resolution and default figure size.

# %%
#>>>RUN

import numpy as np

#set plot resolution
#%config InlineBackend.figure_format = 'retina'

#set default figure size
#plt.rcParams['figure.figsize'] = (9,6)

# %% [markdown]
# <a name='section_17_1'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L17.1 Power Spectrum</h2>
#
# | [Top](#section_17_0) | [Previous Section](#section_17_0) | [Exercises](#exercises_17_1) | [Next Section](#section_17_2) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L17/slides_L17_01.html', width=970, height=550)
# Out:
#         <iframe
#             width="970"
#             height="550"
#             src="https://mitx-8s50.github.io/slides/L17/slides_L17_01.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <a name='exercises_17_1'></a>
#
# | [Top](#section_17_0) | [Restart Section](#section_17_1) | [Next Section](#section_17_2) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 17.1.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_17_2'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L17.2 Random Processes</h2>
#
# | [Top](#section_17_0) | [Previous Section](#section_17_1) | [Exercises](#exercises_17_2) | [Next Section](#section_17_3) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L17/slides_L17_02.html', width=970, height=550)
# Out:
#         <iframe
#             width="970"
#             height="550"
#             src="https://mitx-8s50.github.io/slides/L17/slides_L17_02.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <a name='exercises_17_2'></a>
#
# | [Top](#section_17_0) | [Restart Section](#section_17_2) | [Next Section](#section_17_3) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 17.2.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_17_3'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L17.3 Spectra of Stationary Random Processes</h2>
#
# | [Top](#section_17_0) | [Previous Section](#section_17_2) | [Exercises](#exercises_17_3) | [Next Section](#section_17_4) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L17/slides_L17_03.html', width=970, height=550)

# %% [markdown]
# <a name='exercises_17_3'></a>
#
# | [Top](#section_17_0) | [Restart Section](#section_17_3) | [Next Section](#section_17_4) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 17.3.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_17_4'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L17.4 Discrete Time-Ordered Data</h2>
#
# | [Top](#section_17_0) | [Previous Section](#section_17_3) | [Exercises](#exercises_17_4) | [Next Section](#section_17_5) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L17/slides_L17_04.html', width=970, height=550)

# %% [markdown]
# <a name='exercises_17_4'></a>
#
# | [Top](#section_17_0) | [Restart Section](#section_17_4) | [Next Section](#section_17_5) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 17.4.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_17_5'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L17.5 Maximum Likelihood Signal Estimation</h2>
#
# | [Top](#section_17_0) | [Previous Section](#section_17_4) | [Exercises](#exercises_17_5) | [Next Section](#section_17_6) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L17/slides_L17_05.html', width=970, height=550)

# %% [markdown]
# <a name='exercises_17_5'></a>
#
# | [Top](#section_17_0) | [Restart Section](#section_17_5) | [Next Section](#section_17_6) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 17.5.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_17_6'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L17.6 DFT Matrix</h2>
#
# | [Top](#section_17_0) | [Previous Section](#section_17_5) | [Exercises](#exercises_17_6) | [Next Section](#section_17_7) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L17/slides_L17_06.html', width=970, height=550)

# %% [markdown]
# <a name='exercises_17_6'></a>
#
# | [Top](#section_17_0) | [Restart Section](#section_17_6) | [Next Section](#section_17_7) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 17.6.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_17_7'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L17.7 Noise-Weighting the Data</h2>
#
# | [Top](#section_17_0) | [Previous Section](#section_17_6) | [Exercises](#exercises_17_7) | [Next Section](#section_17_8) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L17/slides_L17_07.html', width=970, height=550)

# %% [markdown]
# <a name='exercises_17_7'></a>
#
# | [Top](#section_17_0) | [Restart Section](#section_17_7) | [Next Section](#section_17_8) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 17.7.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>

# %% [markdown]
# <a name='section_17_8'></a>
# <hr style="height: 1px;">
#
# ## <h2 style="border:1px; border-style:solid; padding: 0.25em; color: #FFFFFF; background-color: #90409C">L17.8 Map Power Spectrum</h2>
#
# | [Top](#section_17_0) | [Previous Section](#section_17_7) | [Exercises](#exercises_17_8) |

# %% [markdown]
# <h3>Slides</h3>
#
# Run the code below to view the slides for this section.

# %%
#>>>RUN

from IPython.display import IFrame
IFrame(src='https://mitx-8s50.github.io/slides/L17/slides_L17_08.html', width=970, height=550)
# Out:
#         <iframe
#             width="970"
#             height="550"
#             src="https://mitx-8s50.github.io/slides/L17/slides_L17_08.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <a name='exercises_17_8'></a>
#
# | [Top](#section_17_0) | [Restart Section](#section_17_8) |

# %% [markdown]
# ### <span style="border:3px; border-style:solid; padding: 0.15em; border-color: #90409C; color: #90409C;">Exercise 17.8.1</span>
#
# text

# %%
#>>>EXERCISE
# Use this cell for drafting your solution (if desired),
# then enter your solution in the interactive problem online to be graded.

def exp_func(x):
    return 0

# %% [markdown]
# ### <span style="color: #90409C;">*>>> Follow-up (ungraded)*</span>
#
#
# ><span style="color: #90409C;">*TEXT*</span>
